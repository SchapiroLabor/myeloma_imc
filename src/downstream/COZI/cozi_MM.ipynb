# %%
import anndata
import pandas as pd
import scimap as sm
import scanpy as sc
import warnings
import numpy as np
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Phenotype5 for grouped and Phenotype4 for subtyped immune cells
phenotype = 'Phenotype5'
path_to_h5ad = './../data/202503cells_spatial_count.h5ad'
adata = anndata.read_h5ad(path_to_h5ad)

# %%
### summarize immune cells

# Create Phenotype5 column being the same as Phenotype4
adata.obs['Phenotype5'] = adata.obs['Phenotype4']

# Add the new category if it's categorical
if isinstance(adata.obs['Phenotype5'].dtype, pd.CategoricalDtype):
    adata.obs['Phenotype5'] = adata.obs['Phenotype5'].cat.add_categories(
        ['Immune cells']
    )

# Update the category for Ki67+ entries
adata.obs.loc[
    (adata.obs['Phenotype5'].isin(['CD8+Tcells', 'CD4+Tcells', 'Dendritic Cells', 'Macrophages/Monocytes', 'Neutrophils', 'activated Macrophages/Monocytes'])), 
    'Phenotype5'
] = 'Immune cells'

# %%
# run spatial interaction analysis
spatial = sm.tl.spatial_interaction (adata,
                         x_coordinate='X_centroid',
                         y_coordinate='Y_centroid',
                         phenotype=phenotype,
                         method='delaunay', 
                         permutation=300,
                         imageid='image_ID',
                         cond_counts_threshold = 10,
                         subset=None,
                         pval_method='zscore',
                         normalization='conditional',
                         verbose=True,
                         label='scimap_delaunay_cozi')
# Out:
# Processing Image: ['TS-373_IMC77_B_001.csv']
# Categories (1, object): ['TS-373_IMC77_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 55.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC03_MGUS_002.csv']
# Categories (1, object): ['TS-373_IMC03_MGUS_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 35.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC04_MGUS_002.csv']
# Categories (1, object): ['TS-373_IMC04_MGUS_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 44.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC72_MGUS_001.csv']
# Categories (1, object): ['TS-373_IMC72_MGUS_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 18.8% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC12_UB_001.csv']
# Categories (1, object): ['TS-373_IMC12_UB_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 42.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC86_B_002.csv']
# Categories (1, object): ['TS-373_IMC86_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 21.9% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC42_B_001.csv']
# Categories (1, object): ['TS-373_IMC42_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 30.9% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC35_B_002.csv']
# Categories (1, object): ['TS-373_IMC35_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 40.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC38_B_001.csv']
# Categories (1, object): ['TS-373_IMC38_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 50.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC90.1_B_001.csv']
# Categories (1, object): ['TS-373_IMC90.1_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 54.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC56_B_001.csv']
# Categories (1, object): ['TS-373_IMC56_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 28.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC92_B_002.csv']
# Categories (1, object): ['TS-373_IMC92_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 20.3% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC37-1_MGUS_001.csv']
# Categories (1, object): ['TS-373_IMC37-1_MGUS_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 28.4% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC77_B_002.csv']
# Categories (1, object): ['TS-373_IMC77_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 55.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC03_MGUS_001.csv']
# Categories (1, object): ['TS-373_IMC03_MGUS_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 21.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC04_MGUS_001.csv']
# Categories (1, object): ['TS-373_IMC04_MGUS_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 23.5% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC12_UB_002.csv']
# Categories (1, object): ['TS-373_IMC12_UB_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 33.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC72_MGUS_002.csv']
# Categories (1, object): ['TS-373_IMC72_MGUS_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 29.6% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC86_B_001.csv']
# Categories (1, object): ['TS-373_IMC86_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 14.1% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC35_B_001.csv']
# Categories (1, object): ['TS-373_IMC35_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 30.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC38_B_002.csv']
# Categories (1, object): ['TS-373_IMC38_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 35.8% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC90.1_B_002.csv']
# Categories (1, object): ['TS-373_IMC90.1_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 41.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC56_B_002.csv']
# Categories (1, object): ['TS-373_IMC56_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 41.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC92_B_001.csv']
# Categories (1, object): ['TS-373_IMC92_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 37.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC33_B_002.csv']
# Categories (1, object): ['TS-373_IMC33_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 27.2% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC80_B_002.csv']
# Categories (1, object): ['TS-373_IMC80_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 37.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC49_B_002.csv']
# Categories (1, object): ['TS-373_IMC49_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 39.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC44_B_001.csv']
# Categories (1, object): ['TS-373_IMC44_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 14.1% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC50_B_001.csv']
# Categories (1, object): ['TS-373_IMC50_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 46.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC78_UB_001.csv']
# Categories (1, object): ['TS-373_IMC78_UB_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 48.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC27_B_002.csv']
# Categories (1, object): ['TS-373_IMC27_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 31.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC71_B_001.csv']
# Categories (1, object): ['TS-373_IMC71_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 43.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC05_MGUS_002.csv']
# Categories (1, object): ['TS-373_IMC05_MGUS_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 28.4% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC42_B_002.csv']
# Categories (1, object): ['TS-373_IMC42_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 38.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC68_B_002.csv']
# Categories (1, object): ['TS-373_IMC68_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 41.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC02_MGUS_002.csv']
# Categories (1, object): ['TS-373_IMC02_MGUS_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 18.5% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC65_B_001.csv']
# Categories (1, object): ['TS-373_IMC65_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 28.4% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC33_B_001.csv']
# Categories (1, object): ['TS-373_IMC33_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 29.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC80_B_001.csv']
# Categories (1, object): ['TS-373_IMC80_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 33.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC49_B_001.csv']
# Categories (1, object): ['TS-373_IMC49_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 39.5% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC44_B_002.csv']
# Categories (1, object): ['TS-373_IMC44_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 33.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC50_B_002.csv']
# Categories (1, object): ['TS-373_IMC50_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 42.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC24_B_009.csv']
# Categories (1, object): ['TS-373_IMC24_B_009.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 33.3% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC78_UB_002.csv']
# Categories (1, object): ['TS-373_IMC78_UB_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 33.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC27_B_001.csv']
# Categories (1, object): ['TS-373_IMC27_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 47.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC71_B_002.csv']
# Categories (1, object): ['TS-373_IMC71_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 43.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC05_MGUS_001.csv']
# Categories (1, object): ['TS-373_IMC05_MGUS_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 42.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC68_B_001.csv']
# Categories (1, object): ['TS-373_IMC68_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 31.2% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC65_B_002.csv']
# Categories (1, object): ['TS-373_IMC65_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 32.1% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC02_MGUS_001.csv']
# Categories (1, object): ['TS-373_IMC02_MGUS_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 21.9% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC01_UB_002.csv']
# Categories (1, object): ['TS-373_IMC01_UB_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 29.6% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC62_B_001.csv']
# Categories (1, object): ['TS-373_IMC62_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 30.9% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC15_B_002.csv']
# Categories (1, object): ['TS-373_IMC15_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 36.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC20_B_002.csv']
# Categories (1, object): ['TS-373_IMC20_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 44.4% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC57_B_001.csv']
# Categories (1, object): ['TS-373_IMC57_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 38.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC93_B_002.csv']
# Categories (1, object): ['TS-373_IMC93_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 38.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC55-1_UB_002.csv']
# Categories (1, object): ['TS-373_IMC55-1_UB_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 32.1% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC43_B_001.csv']
# Categories (1, object): ['TS-373_IMC43_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 22.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC34_B_002.csv']
# Categories (1, object): ['TS-373_IMC34_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 44.4% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC39_B_001.csv']
# Categories (1, object): ['TS-373_IMC39_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 39.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC01_UB_001.csv']
# Categories (1, object): ['TS-373_IMC01_UB_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 19.8% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC62_B_002.csv']
# Categories (1, object): ['TS-373_IMC62_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 28.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC15_B_001.csv']
# Categories (1, object): ['TS-373_IMC15_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 25.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC20_B_001.csv']
# Categories (1, object): ['TS-373_IMC20_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 37.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC57_B_002.csv']
# Categories (1, object): ['TS-373_IMC57_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 36.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC93_B_001.csv']
# Categories (1, object): ['TS-373_IMC93_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 34.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC55-1_UB_001.csv']
# Categories (1, object): ['TS-373_IMC55-1_UB_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 41.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC43_B_002.csv']
# Categories (1, object): ['TS-373_IMC43_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 35.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC34_B_001.csv']
# Categories (1, object): ['TS-373_IMC34_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 41.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC39_B_002.csv']
# Categories (1, object): ['TS-373_IMC39_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 48.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC95_B_002.csv']
# Categories (1, object): ['TS-373_IMC95_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 43.8% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC75-1_B_001.csv']
# Categories (1, object): ['TS-373_IMC75-1_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 33.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC26_B_002.csv']
# Categories (1, object): ['TS-373_IMC26_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 33.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC81_B_002.csv']
# Categories (1, object): ['TS-373_IMC81_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 31.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC48_B_002.csv']
# Categories (1, object): ['TS-373_IMC48_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 35.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC45_B_001.csv']
# Categories (1, object): ['TS-373_IMC45_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 43.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC85_UB_001.csv']
# Categories (1, object): ['TS-373_IMC85_UB_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 35.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC69_B_002.csv']
# Categories (1, object): ['TS-373_IMC69_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 39.5% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC64_B_001.csv']
# Categories (1, object): ['TS-373_IMC64_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 50.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC60-1_B_002.csv']
# Categories (1, object): ['TS-373_IMC60-1_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 32.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC95_B_001.csv']
# Categories (1, object): ['TS-373_IMC95_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 48.1% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC75-1_B_002.csv']
# Categories (1, object): ['TS-373_IMC75-1_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 33.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC26_B_001.csv']
# Categories (1, object): ['TS-373_IMC26_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 12.5% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC81_B_001.csv']
# Categories (1, object): ['TS-373_IMC81_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 31.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC48_B_001.csv']
# Categories (1, object): ['TS-373_IMC48_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 24.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC45_B_002.csv']
# Categories (1, object): ['TS-373_IMC45_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 44.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC85_UB_002.csv']
# Categories (1, object): ['TS-373_IMC85_UB_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 42.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC69_B_001.csv']
# Categories (1, object): ['TS-373_IMC69_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 39.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC64_B_002.csv']
# Categories (1, object): ['TS-373_IMC64_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 38.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC60-1_B_001.csv']
# Categories (1, object): ['TS-373_IMC60-1_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 47.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC89_B_001.csv']
# Categories (1, object): ['TS-373_IMC89_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 31.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC84_B_002.csv']
# Categories (1, object): ['TS-373_IMC84_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 76.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC23_B_002.csv']
# Categories (1, object): ['TS-373_IMC23_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 50.6% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC21_UB_002.csv']
# Categories (1, object): ['TS-373_IMC21_UB_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 25.9% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC54_B_001.csv']
# Categories (1, object): ['TS-373_IMC54_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 36.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC40-1_B_002.csv']
# Categories (1, object): ['TS-373_IMC40-1_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 40.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC30_UB_001.csv']
# Categories (1, object): ['TS-373_IMC30_UB_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 20.3% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC82_MGUS_002.csv']
# Categories (1, object): ['TS-373_IMC82_MGUS_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 50.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC07_UB_001.csv']
# Categories (1, object): ['TS-373_IMC07_UB_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 49.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC59_MGUS_001.csv']
# Categories (1, object): ['TS-373_IMC59_MGUS_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 54.3% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC67-1_B_001.csv']
# Categories (1, object): ['TS-373_IMC67-1_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 35.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC89_B_002.csv']
# Categories (1, object): ['TS-373_IMC89_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 32.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC84_B_001.csv']
# Categories (1, object): ['TS-373_IMC84_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 55.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC23_B_001.csv']
# Categories (1, object): ['TS-373_IMC23_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 27.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC59_MGUS_003.csv']
# Categories (1, object): ['TS-373_IMC59_MGUS_003.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 25.9% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC21_UB_001.csv']
# Categories (1, object): ['TS-373_IMC21_UB_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 56.2% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC54_B_002.csv']
# Categories (1, object): ['TS-373_IMC54_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 26.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC30_UB_002.csv']
# Categories (1, object): ['TS-373_IMC30_UB_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 24.7% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC82_MGUS_001.csv']
# Categories (1, object): ['TS-373_IMC82_MGUS_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 43.2% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC40-1_B_001.csv']
# Categories (1, object): ['TS-373_IMC40-1_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 33.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC07_UB_002.csv']
# Categories (1, object): ['TS-373_IMC07_UB_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 56.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC59_MGUS_002.csv']
# Categories (1, object): ['TS-373_IMC59_MGUS_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 16.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC67-1_B_002.csv']
# Categories (1, object): ['TS-373_IMC67-1_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 28.4% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC09_B_001.csv']
# Categories (1, object): ['TS-373_IMC09_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 44.4% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC29_UB_002.csv']
# Categories (1, object): ['TS-373_IMC29_UB_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 45.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC31_B_002.csv']
# Categories (1, object): ['TS-373_IMC31_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 25.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC96_B_002.csv']
# Categories (1, object): ['TS-373_IMC96_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 33.3% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC52_B_001.csv']
# Categories (1, object): ['TS-373_IMC52_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 42.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC25_B_002.csv']
# Categories (1, object): ['TS-373_IMC25_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 45.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC28_B_001.csv']
# Categories (1, object): ['TS-373_IMC28_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 57.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC09_B_002.csv']
# Categories (1, object): ['TS-373_IMC09_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 40.7% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC29_UB_001.csv']
# Categories (1, object): ['TS-373_IMC29_UB_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 39.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC31_B_001.csv']
# Categories (1, object): ['TS-373_IMC31_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 24.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC96_B_001.csv']
# Categories (1, object): ['TS-373_IMC96_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 18.5% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC52_B_002.csv']
# Categories (1, object): ['TS-373_IMC52_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 46.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC25_B_001.csv']
# Categories (1, object): ['TS-373_IMC25_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 42.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC28_B_002.csv']
# Categories (1, object): ['TS-373_IMC28_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 41.7% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC18-2_UB_001.csv']
# Categories (1, object): ['TS-373_IMC18-2_UB_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 45.7% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC58_B_002.csv']
# Categories (1, object): ['TS-373_IMC58_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 44.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC18-1_MGUS_001.csv']
# Categories (1, object): ['TS-373_IMC18-1_MGUS_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 36.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC08_UB_002.csv']
# Categories (1, object): ['TS-373_IMC08_UB_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 42.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC74_B_001.csv']
# Categories (1, object): ['TS-373_IMC74_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 32.1% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC18-2_UB_002.csv']
# Categories (1, object): ['TS-373_IMC18-2_UB_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 43.2% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC58_B_001.csv']
# Categories (1, object): ['TS-373_IMC58_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 27.2% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC18-1_MGUS_002.csv']
# Categories (1, object): ['TS-373_IMC18-1_MGUS_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 37.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC08_UB_001.csv']
# Categories (1, object): ['TS-373_IMC08_UB_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 41.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC74_B_002.csv']
# Categories (1, object): ['TS-373_IMC74_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 32.1% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC66_B_001.csv']
# Categories (1, object): ['TS-373_IMC66_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 29.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC16-1_MGUS_001.csv']
# Categories (1, object): ['TS-373_IMC16-1_MGUS_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 37.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC87-1_UB_002.csv']
# Categories (1, object): ['TS-373_IMC87-1_UB_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 25.9% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC41_MGUS_002.csv']
# Categories (1, object): ['TS-373_IMC41_MGUS_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 26.6% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC53_B_001.csv']
# Categories (1, object): ['TS-373_IMC53_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 14.1% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC24_B_002.csv']
# Categories (1, object): ['TS-373_IMC24_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 35.8% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC47_B_001.csv']
# Categories (1, object): ['TS-373_IMC47_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 31.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC83_B_002.csv']
# Categories (1, object): ['TS-373_IMC83_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 30.9% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC16-1_MGUS_002.csv']
# Categories (1, object): ['TS-373_IMC16-1_MGUS_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 23.5% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC66_B_002.csv']
# Categories (1, object): ['TS-373_IMC66_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 23.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC41_MGUS_001.csv']
# Categories (1, object): ['TS-373_IMC41_MGUS_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 31.2% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC87-1_UB_001.csv']
# Categories (1, object): ['TS-373_IMC87-1_UB_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 12.5% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC53_B_002.csv']
# Categories (1, object): ['TS-373_IMC53_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 35.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC47_B_002.csv']
# Categories (1, object): ['TS-373_IMC47_B_002.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 41.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.
# Processing Image: ['TS-373_IMC83_B_001.csv']
# Categories (1, object): ['TS-373_IMC83_B_001.csv']
# Performing Delaunay triangulation to identify neighbours for every cell
# Mapping phenotype to neighbors
# Performing 300 permutations
# Consolidating the permutation results
# Warning: 46.0% of cell type pairs have counts below 10. Results for these pairs should be interpreted with caution.

# %%
# normalize scores by the total number of cells in a sample
# get how many cells are in each sample
total_cells = adata.obs['image_ID'].value_counts()
total_cells
# Out:
# image_ID
# TS-373_IMC28_B_002.csv       12605
# TS-373_IMC72_MGUS_001.csv    11513
# TS-373_IMC29_UB_002.csv      11288
# TS-373_IMC89_B_001.csv       11013
# TS-373_IMC21_UB_001.csv      10915
#                              ...
# TS-373_IMC85_UB_001.csv       3420
# TS-373_IMC89_B_002.csv        3302
# TS-373_IMC45_B_002.csv        3297
# TS-373_IMC81_B_002.csv        2674
# TS-373_IMC59_MGUS_001.csv     1739
# Name: count, Length: 152, dtype: int64

# %%
adata.obs['disease2'] = adata.obs['disease2'].astype('category')
adata.obs['disease2'] = adata.obs['disease2'].cat.reorder_categories(['MM_BD', 'MM_noBD', 'MGUS', 'SMM'])
adata.obs = adata.obs.sort_values('disease2')

save_df = spatial.uns['scimap_delaunay_cozi']
save_df['phenotype'] = save_df['phenotype'].astype(str)
save_df['neighbour_phenotype'] = save_df['neighbour_phenotype'].astype(str)
save_df['new_column'] = save_df['phenotype'] + "_" + save_df['neighbour_phenotype']
save_df = save_df.drop(columns=['phenotype', 'neighbour_phenotype']).set_index('new_column')

#normalize scores by sqr of total number of cells in a sample
save_df.columns = save_df.columns.str.replace('zscore_', '')
for col in save_df.columns:
    if col in total_cells:
        save_df[col] = save_df[col] / np.sqrt(total_cells[col])

df_out = save_df.transpose()
df_out.columns = df_out.columns.str.replace(r'\.0', '', regex=True)
df_out = df_out[~df_out.index.str.contains('pvalue|count')]
df_out.columns = df_out.columns.str.replace('zscore_', '')

df_out.to_csv('./../../Myeloma_Standal/results/colocalization_csv/250623COZI_grouped_immune_normalized.csv')

# %%
df_out
# Out:
# new_column                                       Adipocytes_Adipocytes  \
# TS-373_IMC77_B_001.csv                                        0.054949
# cond_cells_percentage_TS-373_IMC77_B_001.csv                  0.459770
# TS-373_IMC03_MGUS_002.csv                                     0.005190
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv               0.240741
# TS-373_IMC04_MGUS_002.csv                                     0.092674
# ...                                                                ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv                  0.716374
# TS-373_IMC47_B_002.csv                                        0.058939
# cond_cells_percentage_TS-373_IMC47_B_002.csv                  0.500000
# TS-373_IMC83_B_001.csv                                        0.032446
# cond_cells_percentage_TS-373_IMC83_B_001.csv                  0.484848
#
# new_column                                       Adipocytes_Endothelial cells  \
# TS-373_IMC77_B_001.csv                                              -0.024512
# cond_cells_percentage_TS-373_IMC77_B_001.csv                         0.022989
# TS-373_IMC03_MGUS_002.csv                                           -0.091782
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv                      0.018519
# TS-373_IMC04_MGUS_002.csv                                           -0.134992
# ...                                                                       ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv                         0.283626
# TS-373_IMC47_B_002.csv                                               0.041461
# cond_cells_percentage_TS-373_IMC47_B_002.csv                         0.152174
# TS-373_IMC83_B_001.csv                                               0.027082
# cond_cells_percentage_TS-373_IMC83_B_001.csv                         0.151515
#
# new_column                                       Adipocytes_HSCs  \
# TS-373_IMC77_B_001.csv                                 -0.026232
# cond_cells_percentage_TS-373_IMC77_B_001.csv            0.000000
# TS-373_IMC03_MGUS_002.csv                              -0.132071
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv         0.148148
# TS-373_IMC04_MGUS_002.csv                              -0.166576
# ...                                                          ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv            0.090643
# TS-373_IMC47_B_002.csv                                 -0.130158
# cond_cells_percentage_TS-373_IMC47_B_002.csv            0.043478
# TS-373_IMC83_B_001.csv                                 -0.151089
# cond_cells_percentage_TS-373_IMC83_B_001.csv            0.060606
#
# new_column                                       Adipocytes_Immune cells  \
# TS-373_IMC77_B_001.csv                                         -0.057748
# cond_cells_percentage_TS-373_IMC77_B_001.csv                    0.908046
# TS-373_IMC03_MGUS_002.csv                                      -0.027103
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv                 0.907407
# TS-373_IMC04_MGUS_002.csv                                      -0.113323
# ...                                                                  ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv                    0.608187
# TS-373_IMC47_B_002.csv                                         -0.067712
# cond_cells_percentage_TS-373_IMC47_B_002.csv                    0.923913
# TS-373_IMC83_B_001.csv                                         -0.070039
# cond_cells_percentage_TS-373_IMC83_B_001.csv                    0.939394
#
# new_column                                       Adipocytes_MPO+  \
# TS-373_IMC77_B_001.csv                                  0.014985
# cond_cells_percentage_TS-373_IMC77_B_001.csv            0.379310
# TS-373_IMC03_MGUS_002.csv                               0.002523
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv         0.537037
# TS-373_IMC04_MGUS_002.csv                               0.011489
# ...                                                          ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv            0.146199
# TS-373_IMC47_B_002.csv                                  0.013603
# cond_cells_percentage_TS-373_IMC47_B_002.csv            0.391304
# TS-373_IMC83_B_001.csv                                  0.036588
# cond_cells_percentage_TS-373_IMC83_B_001.csv            0.242424
#
# new_column                                       Adipocytes_Osteoblast lineage  \
# TS-373_IMC77_B_001.csv                                               -0.011259
# cond_cells_percentage_TS-373_IMC77_B_001.csv                          0.011494
# TS-373_IMC03_MGUS_002.csv                                            -0.035993
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv                       0.037037
# TS-373_IMC04_MGUS_002.csv                                            -0.091432
# ...                                                                        ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv                          0.035088
# TS-373_IMC47_B_002.csv                                               -0.039793
# cond_cells_percentage_TS-373_IMC47_B_002.csv                          0.021739
# TS-373_IMC83_B_001.csv                                               -0.022594
# cond_cells_percentage_TS-373_IMC83_B_001.csv                          0.045455
#
# new_column                                       Adipocytes_Osteoclasts  \
# TS-373_IMC77_B_001.csv                                        -0.012124
# cond_cells_percentage_TS-373_IMC77_B_001.csv                   0.000000
# TS-373_IMC03_MGUS_002.csv                                     -0.006825
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv                0.000000
# TS-373_IMC04_MGUS_002.csv                                     -0.012778
# ...                                                                 ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv                   0.000000
# TS-373_IMC47_B_002.csv                                        -0.010097
# cond_cells_percentage_TS-373_IMC47_B_002.csv                   0.000000
# TS-373_IMC83_B_001.csv                                        -0.005878
# cond_cells_percentage_TS-373_IMC83_B_001.csv                   0.000000
#
# new_column                                       Adipocytes_Osteocyte  \
# TS-373_IMC77_B_001.csv                                      -0.164186
# cond_cells_percentage_TS-373_IMC77_B_001.csv                 0.011494
# TS-373_IMC03_MGUS_002.csv                                   -0.134189
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv              0.055556
# TS-373_IMC04_MGUS_002.csv                                   -0.114675
# ...                                                               ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv                 0.011696
# TS-373_IMC47_B_002.csv                                      -0.044875
# cond_cells_percentage_TS-373_IMC47_B_002.csv                 0.065217
# TS-373_IMC83_B_001.csv                                      -0.011633
# cond_cells_percentage_TS-373_IMC83_B_001.csv                 0.000000
#
# new_column                                       Adipocytes_Plasma Cells/MM cells  \
# TS-373_IMC77_B_001.csv                                                   0.009796
# cond_cells_percentage_TS-373_IMC77_B_001.csv                             0.195402
# TS-373_IMC03_MGUS_002.csv                                                0.029947
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv                          0.537037
# TS-373_IMC04_MGUS_002.csv                                                0.066032
# ...                                                                           ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv                             0.967836
# TS-373_IMC47_B_002.csv                                                  -0.017220
# cond_cells_percentage_TS-373_IMC47_B_002.csv                             0.739130
# TS-373_IMC83_B_001.csv                                                   0.041516
# cond_cells_percentage_TS-373_IMC83_B_001.csv                             0.515152
#
# new_column                                       Adipocytes_Unknown  ...  \
# TS-373_IMC77_B_001.csv                                     0.061592  ...
# cond_cells_percentage_TS-373_IMC77_B_001.csv               0.919540  ...
# TS-373_IMC03_MGUS_002.csv                                  0.041051  ...
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv            0.759259  ...
# TS-373_IMC04_MGUS_002.csv                                  0.058970  ...
# ...                                                             ...  ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv               0.228070  ...
# TS-373_IMC47_B_002.csv                                     0.076529  ...
# cond_cells_percentage_TS-373_IMC47_B_002.csv               0.760870  ...
# TS-373_IMC83_B_001.csv                                     0.086875  ...
# cond_cells_percentage_TS-373_IMC83_B_001.csv               0.575758  ...
#
# new_column                                       Unknown_Adipocytes  \
# TS-373_IMC77_B_001.csv                                     0.100022
# cond_cells_percentage_TS-373_IMC77_B_001.csv               0.113267
# TS-373_IMC03_MGUS_002.csv                                  0.026412
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv            0.063479
# TS-373_IMC04_MGUS_002.csv                                  0.111155
# ...                                                             ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv               0.280769
# TS-373_IMC47_B_002.csv                                     0.066281
# cond_cells_percentage_TS-373_IMC47_B_002.csv               0.165738
# TS-373_IMC83_B_001.csv                                     0.059530
# cond_cells_percentage_TS-373_IMC83_B_001.csv               0.126984
#
# new_column                                       Unknown_Endothelial cells  \
# TS-373_IMC77_B_001.csv                                            0.077495
# cond_cells_percentage_TS-373_IMC77_B_001.csv                      0.018148
# TS-373_IMC03_MGUS_002.csv                                         0.128062
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv                   0.090684
# TS-373_IMC04_MGUS_002.csv                                         0.087349
# ...                                                                    ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv                      0.226923
# TS-373_IMC47_B_002.csv                                            0.089815
# cond_cells_percentage_TS-373_IMC47_B_002.csv                      0.097493
# TS-373_IMC83_B_001.csv                                            0.021383
# cond_cells_percentage_TS-373_IMC83_B_001.csv                      0.079365
#
# new_column                                       Unknown_HSCs  \
# TS-373_IMC77_B_001.csv                               0.259313
# cond_cells_percentage_TS-373_IMC77_B_001.csv         0.007509
# TS-373_IMC03_MGUS_002.csv                            0.048612
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv      0.084913
# TS-373_IMC04_MGUS_002.csv                            0.024307
# ...                                                       ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv         0.076923
# TS-373_IMC47_B_002.csv                               0.075265
# cond_cells_percentage_TS-373_IMC47_B_002.csv         0.025070
# TS-373_IMC83_B_001.csv                               0.029439
# cond_cells_percentage_TS-373_IMC83_B_001.csv         0.091270
#
# new_column                                       Unknown_Immune cells  \
# TS-373_IMC77_B_001.csv                                      -0.322964
# cond_cells_percentage_TS-373_IMC77_B_001.csv                 0.795995
# TS-373_IMC03_MGUS_002.csv                                   -0.104185
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv              0.851608
# TS-373_IMC04_MGUS_002.csv                                   -0.252438
# ...                                                               ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv                 0.657692
# TS-373_IMC47_B_002.csv                                      -0.069994
# cond_cells_percentage_TS-373_IMC47_B_002.csv                 0.850975
# TS-373_IMC83_B_001.csv                                      -0.150473
# cond_cells_percentage_TS-373_IMC83_B_001.csv                 0.970238
#
# new_column                                       Unknown_MPO+  \
# TS-373_IMC77_B_001.csv                               0.140312
# cond_cells_percentage_TS-373_IMC77_B_001.csv         0.439925
# TS-373_IMC03_MGUS_002.csv                            0.047474
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv      0.516900
# TS-373_IMC04_MGUS_002.csv                            0.077312
# ...                                                       ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv         0.311538
# TS-373_IMC47_B_002.csv                               0.141143
# cond_cells_percentage_TS-373_IMC47_B_002.csv         0.373259
# TS-373_IMC83_B_001.csv                               0.106937
# cond_cells_percentage_TS-373_IMC83_B_001.csv         0.248016
#
# new_column                                       Unknown_Osteoblast lineage  \
# TS-373_IMC77_B_001.csv                                            -0.001270
# cond_cells_percentage_TS-373_IMC77_B_001.csv                       0.008135
# TS-373_IMC03_MGUS_002.csv                                          0.069154
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv                    0.037098
# TS-373_IMC04_MGUS_002.csv                                          0.031167
# ...                                                                     ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv                       0.115385
# TS-373_IMC47_B_002.csv                                            -0.004703
# cond_cells_percentage_TS-373_IMC47_B_002.csv                       0.015320
# TS-373_IMC83_B_001.csv                                             0.075734
# cond_cells_percentage_TS-373_IMC83_B_001.csv                       0.021825
#
# new_column                                       Unknown_Osteoclasts  \
# TS-373_IMC77_B_001.csv                                      0.213667
# cond_cells_percentage_TS-373_IMC77_B_001.csv                0.006884
# TS-373_IMC03_MGUS_002.csv                                  -0.708324
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv             0.000000
# TS-373_IMC04_MGUS_002.csv                                   0.182979
# ...                                                              ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv                0.003846
# TS-373_IMC47_B_002.csv                                     -0.079356
# cond_cells_percentage_TS-373_IMC47_B_002.csv                0.001393
# TS-373_IMC83_B_001.csv                                     -0.023560
# cond_cells_percentage_TS-373_IMC83_B_001.csv                0.001984
#
# new_column                                       Unknown_Osteocyte  \
# TS-373_IMC77_B_001.csv                                    0.203864
# cond_cells_percentage_TS-373_IMC77_B_001.csv              0.055069
# TS-373_IMC03_MGUS_002.csv                                 0.210480
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv           0.085738
# TS-373_IMC04_MGUS_002.csv                                 0.388691
# ...                                                            ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv              0.023077
# TS-373_IMC47_B_002.csv                                    0.155312
# cond_cells_percentage_TS-373_IMC47_B_002.csv              0.027855
# TS-373_IMC83_B_001.csv                                   -0.102567
# cond_cells_percentage_TS-373_IMC83_B_001.csv              0.009921
#
# new_column                                       Unknown_Plasma Cells/MM cells  \
# TS-373_IMC77_B_001.csv                                                0.220131
# cond_cells_percentage_TS-373_IMC77_B_001.csv                          0.173342
# TS-373_IMC03_MGUS_002.csv                                             0.065099
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv                       0.466612
# TS-373_IMC04_MGUS_002.csv                                             0.105496
# ...                                                                        ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv                          0.800000
# TS-373_IMC47_B_002.csv                                               -0.120735
# cond_cells_percentage_TS-373_IMC47_B_002.csv                          0.647632
# TS-373_IMC83_B_001.csv                                               -0.007110
# cond_cells_percentage_TS-373_IMC83_B_001.csv                          0.365079
#
# new_column                                       Unknown_Unknown
# TS-373_IMC77_B_001.csv                                  0.574460
# cond_cells_percentage_TS-373_IMC77_B_001.csv            0.923029
# TS-373_IMC03_MGUS_002.csv                               0.344115
# cond_cells_percentage_TS-373_IMC03_MGUS_002.csv         0.832646
# TS-373_IMC04_MGUS_002.csv                               0.513692
# ...                                                          ...
# cond_cells_percentage_TS-373_IMC53_B_002.csv            0.611538
# TS-373_IMC47_B_002.csv                                  0.373885
# cond_cells_percentage_TS-373_IMC47_B_002.csv            0.817549
# TS-373_IMC83_B_001.csv                                  0.300203
# cond_cells_percentage_TS-373_IMC83_B_001.csv            0.748016
#
# [304 rows x 100 columns]
